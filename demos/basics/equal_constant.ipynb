# %%
import pyclesperanto as cle
import numpy as np

cle.get_device()
# Out:
# (OpenCL) NVIDIA GeForce RTX 2080 SUPER (OpenCL 3.0 CUDA)
# 	Type: GPU
# 	Compute Units: 48
# 	Global Memory Size: 8366 MB
# 	Maximum Object Size: 2091 MB

# %%
img = np.zeros((100,100))
img[25:75, 25:75] = 1

image = cle.push(img)

cle.imshow(image)

# %%
binary_image = (image == 1)

cle.imshow(binary_image)

# %%
another_binary_image = cle.equal_constant(binary_image)
cle.imshow(another_binary_image)

# %%
# The reason why this image is the inverted version of `binary_image` is that `constant` 
# in `equal_constant` has a default value: 0. Thus, you're checking if `binary_image` 
# is _equal to the constant 0_. See also documentation:
help(cle.equal_constant)
# Out:
# Help on function equal_constant in module pyclesperanto:
#
# equal_constant(input_image: Union[numpy.ndarray, pyclesperanto._pyclesperanto._Array], output_image: Union[numpy.ndarray, pyclesperanto._pyclesperanto._Array] = None, scalar: float = 0, device: pyclesperanto._pyclesperanto._Device = None) -> Union[numpy.ndarray, pyclesperanto._pyclesperanto._Array]
