# %% [markdown]
# # AI-based code suggestions: bia-bob
#
# The [bia-bob project](https://github.com/haesleinhuepf/bia-bob) allows to use large language models for generating code in Jupyter notebooks. bia-bob is aware of pyclesperanto and can guide you how to use it. Just write your prompt below "%%bob", e.g. mentioning that you want to use GPU-acceleration for image processing and it may suggest using pyclesperanto.

# %%
import bia_bob

# %%
import numpy as np
image = np.random.random((20,20))

# %%
# %%bob
# Apply a GPU-accelerated Gaussian blur to the `image` and show the result
# Out:
#             <div style="font-size:7pt">
#             This notebook may contain text, code and images generated by artificial intelligence.
#             Used model: gpt-4o-2024-08-06, vision model: gpt-4o-2024-08-06, endpoint: None, bia-bob version: 0.24.0.. Do not enter sensitive or private information and verify generated contents according to good scientific practice. Read more: <a href="https://github.com/haesleinhuepf/bia-bob#disclaimer">https://github.com/haesleinhuepf/bia-bob#disclaimer</a>
#             </div>
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('bob', '', 'Apply a GPU-accelerated Gaussian blur to the `image` and show the result\n')
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/bia_bob/_machinery.py:122, in bob(line, cell)
#     105 supported_file_types_for_generation = [".md", ".txt", ".csv", ".yml", ".yaml", ".json", ".py"]
#     107 task_selection_prompt = f"""
#     108 Given the following prompt, decide which of the following types of tasks we need to perform:
#     109 {TASK_TYPE_CODE_GENERATION}. Code generation: The prompt asks for code to be generated.
#    (...)
#     120 Now, write the number of the task type into the next cell. Print the number only.
#     121 """
# --> 122 response = ask_llm(task_selection_prompt)
#     124 try:
#     125     task_type = int(response.strip().strip("\n").split(".")[0])
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/bia_bob/_utilities.py:13, in ask_llm(prompt, image, chat_history)
#      10 if chat_history is None:
#      11     chat_history = []
# ---> 13 return generate_response(chat_history=chat_history,
#      14                   image=image,
#      15                   model=Context.model,
#      16                   system_prompt="",
#      17                   user_prompt=prompt,
#      18                   vision_system_prompt="")
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/bia_bob/_utilities.py:104, in generate_response(chat_history, image, model, system_prompt, user_prompt, vision_system_prompt)
#      99     full_response = generate_response_from_openai(model, system_prompt, user_prompt, chat_history, image,
#     100                                                   base_url=Context.endpoint, api_key=Context.api_key,
#     101                                                   vision_model=Context.vision_model,
#     102                                                   vision_system_prompt=vision_system_prompt)
#     103 elif "gpt-" in model:
# --> 104     full_response = generate_response_from_openai(model, system_prompt, user_prompt, chat_history, image,
#     105                                                   vision_model=Context.vision_model,
#     106                                                   vision_system_prompt=vision_system_prompt)
#     107 elif model == "gemini" or model == "gemini-pro" or model == "gemini-pro-vision":
#     108     import warnings
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/bia_bob/endpoints/_openai.py:25, in generate_response_from_openai(model, system_prompt, user_prompt, chat_history, image, base_url, api_key, vision_model, vision_system_prompt)
#      23     # init client
#      24     if Context.client is None or not isinstance(Context.client, OpenAI):
# ---> 25         Context.client = OpenAI(**model_init_kwargs)
#      26     client = Context.client
#      27 else:
#
# File ~/Libraries/miniforge3/envs/skbe/lib/python3.12/site-packages/openai/_client.py:105, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     103     api_key = os.environ.get("OPENAI_API_KEY")
#     104 if api_key is None:
# --> 105     raise OpenAIError(
#     106         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     107     )
#     108 self.api_key = api_key
#     110 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
import pyclesperanto as cle
import stackview

# Apply Gaussian blur
blurred_image = cle.gaussian_blur(image, sigma_x=2, sigma_y=2, sigma_z=0)

# Show the result
stackview.insight(blurred_image)
# Out:
# StackViewNDArray([[0.36536744, 0.45027903, 0.5325399 , 0.59676033,
#                    0.63598675, 0.6512185 , 0.6443301 , 0.6144411 ,
#                    0.5642812 , 0.508275  , 0.46957502, 0.46509263,
#                    0.49196616, 0.5307466 , 0.5624593 , 0.580244  ,
#                    0.5865115 , 0.58531225, 0.5792203 , 0.5701569 ],
#                   [0.40017095, 0.46456805, 0.52998596, 0.58364075,
#                    0.6179382 , 0.6324736 , 0.62921053, 0.60794735,
#                    0.5699371 , 0.524873  , 0.49009863, 0.4800092 ,
#                    0.49557963, 0.5251109 , 0.5542827 , 0.573515  ,
#                    0.5783846 , 0.5688357 , 0.54927725, 0.52679247],
#                   [0.4466388 , 0.4900386 , 0.5366867 , 0.5758727 ,
#                    0.59948367, 0.6066649 , 0.60121995, 0.585669  ,
#                    0.56099075, 0.5314934 , 0.5063925 , 0.4950479 ,
#                    0.50105   , 0.520806  , 0.5458866 , 0.56541735,
#                    0.5692848 , 0.553627  , 0.5238435 , 0.490788  ],
#                   [0.4890919 , 0.5159188 , 0.5469786 , 0.5725918 ,
#                    0.58369297, 0.57919383, 0.56602263, 0.5517791 ,
#                    0.5393599 , 0.5282281 , 0.51815534, 0.51116925,
#                    0.5111372 , 0.5211286 , 0.5391486 , 0.5557705 ,
#                    0.55845493, 0.54084486, 0.5077987 , 0.47106975],
#                   [0.48237208, 0.4738749 , 0.46965972, 0.46989807,
#                    0.47229764, 0.47652224, 0.48460057, 0.49587235,
#                    0.5052642 , 0.50876856, 0.50763416, 0.5054831 ,
#                    0.5046281 , 0.5065507 , 0.5115118 , 0.5149519 ,
#                    0.5069363 , 0.47852856, 0.43010452, 0.37332124],
#                   [0.44802582, 0.44126883, 0.43643093, 0.43388295,
#                    0.43339828, 0.43676105, 0.446404  , 0.4608221 ,
#                    0.47458762, 0.48435342, 0.4918545 , 0.49963403,
#                    0.5073678 , 0.5139749 , 0.5190856 , 0.51993996,
#                    0.50987226, 0.48312673, 0.44146678, 0.3950528 ],
#                   [0.44106036, 0.430196  , 0.41971183, 0.4108529 ,
#                    0.4054293 , 0.40678304, 0.41704   , 0.43351823,
#                    0.45066267, 0.46604943, 0.4815284 , 0.4977338 ,
#                    0.5113298 , 0.5191356 , 0.5209084 , 0.51634747,
#                    0.5029021 , 0.47895995, 0.44780317, 0.4168459 ],
#                   [0.46633607, 0.44654036, 0.4262627 , 0.40836027,
#                    0.39638355, 0.39434963, 0.40357605, 0.4204    ,
#                    0.43948567, 0.45929307, 0.48135346, 0.5039332 ,
#                    0.52058375, 0.5264011 , 0.5219151 , 0.5097854 ,
#                    0.49161094, 0.46949667, 0.44774896, 0.43091577],
#                   [0.5164548 , 0.48719004, 0.4567654 , 0.4297303 ,
#                    0.41064194, 0.40334752, 0.4085406 , 0.42254868,
#                    0.44079822, 0.4625399 , 0.48902613, 0.51646477,
#                    0.53523976, 0.5382688 , 0.52681506, 0.5070433 ,
#                    0.48469675, 0.4643207 , 0.44984823, 0.44308132],
#                   [0.58176684, 0.54528624, 0.5070962 , 0.47274643,
#                    0.44665563, 0.4319528 , 0.429593  , 0.43716982,
#                    0.451017  , 0.4707075 , 0.497785  , 0.52788174,
#                    0.5488108 , 0.55045855, 0.5340418 , 0.5095222 ,
#                    0.48688585, 0.47165206, 0.4653911 , 0.46677172],
#                   [0.652553  , 0.6114059 , 0.56849605, 0.5292904 ,
#                    0.4968424 , 0.47335035, 0.4610812 , 0.45979488,
#                    0.46626276, 0.47953054, 0.5021189 , 0.5312077 ,
#                    0.5535203 , 0.5556327 , 0.53779906, 0.5134278 ,
#                    0.49638623, 0.4918446 , 0.4973675 , 0.50796884],
#                   [0.7165891 , 0.67301553, 0.62829477, 0.5868545 ,
#                    0.54957896, 0.5177622 , 0.495552  , 0.4850614 ,
#                    0.482922  , 0.48701882, 0.5012144 , 0.5257172 ,
#                    0.5477272 , 0.5511563 , 0.5349399 , 0.51502603,
#                    0.508046  , 0.51781636, 0.53740424, 0.5583124 ]],
#                  dtype=float32)
