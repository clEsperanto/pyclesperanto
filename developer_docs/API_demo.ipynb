# %%
from skimage.io import imread, imshow
import pyclesperanto as cle

print("pyclesperanto",cle.__version__ , "- running with CLIc",cle.__clic_version__)
# Out:
# pyclesperanto 0.6.5 - running with CLIc 0.6.2

# %%
cle.list_available_devices()
# Out:
# ['NVIDIA GeForce GTX 1050 Ti',
#  'pthread-Intel(R) Core(TM) i7-7820X CPU @ 3.60GHz']

# %%
device = cle.select_device("")
print(device)
# Out:
# <cle::Processor (NVIDIA GeForce GTX 1050 Ti)>

# %%
cle.info() # WIP - not yet implemented
# Out:
# 'NVIDIA GeForce GTX 1050 Ti'

# %%
image = imread("https://imagej.nih.gov/ij/images/blobs.gif")

imshow(image)

# %%
blurred = cle.gaussian_blur(image, sigma_x=1, sigma_y=5)

# %%
cle.imshow(blurred)
