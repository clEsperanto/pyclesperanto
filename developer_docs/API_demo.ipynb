# %%
from skimage.io import imread, imshow
from pyclesperanto import Clesperanto

# %%
cle = Clesperanto()

# %%
cle.list_available_devices()
# Out:
# ['NVIDIA GeForce GTX 1050 Ti']

# %%
cle.select_device("GTX")
# Out:
# 'NVIDIA GeForce GTX 1050 Ti'

# %%
cle.info
# Out:
# [NVIDIA CUDA - NVIDIA GeForce GTX 1050 Ti]
# 	DevicedeviceType: 4
# 	MaxComputeUnits: 6
# 	MaxClockFrequency: 1455
# 	Version: OpenCL 3.0 CUDA
# 	Extensions: cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_fp64 cl_khr_3d_image_writes cl_khr_byte_addressable_store cl_khr_icd cl_khr_gl_sharing cl_nv_compiler_options cl_nv_device_attribute_query cl_nv_pragma_unroll cl_nv_copy_opts cl_nv_create_buffer cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_device_uuid cl_khr_pci_bus_info
# 	GlobalMemorySizeInBytes: 4233035776
# 	LocalMemorySizeInBytes: 49152
# 	MaxMemoryAllocationSizeInBytes: 1058258944
# 	MaxWorkGroupSize: 1024

# %%
image = imread("blobs.tif")

imshow(image)

# %%
blurred = cle.gaussian_blur(image, sigma_x=1, sigma_y=5)

imshow(cle.pull(blurred))
# Out:
# /home/stephane/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
imshow(blurred) # todo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 imshow(blurred)
#
# File ~/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/_io.py:166, in imshow(arr, plugin, **plugin_args)
#     164 if isinstance(arr, str):
#     165     arr = call_plugin('imread', arr, plugin=plugin)
# --> 166 return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#
# File ~/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
#     203     except IndexError:
#     204         raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                            (plugin, kind))
# --> 207 return func(*args, **kwargs)
#
# File ~/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150, in imshow(image, ax, show_cbar, **kwargs)
#     116 """Show the input image and return the current axes.
#     117
#     118 By default, the image is displayed in grayscale, rather than
#    (...)
#     146     The `AxesImage` object returned by `plt.imshow`.
#     147 """
#     148 import matplotlib.pyplot as plt
# --> 150 lo, hi, cmap = _get_display_range(image)
#     152 kwargs.setdefault('interpolation', 'nearest')
#     153 kwargs.setdefault('cmap', cmap)
#
# File ~/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:97, in _get_display_range(image)
#      82 def _get_display_range(image):
#      83     """Return the display range for a given set of image properties.
#      84
#      85     Parameters
#    (...)
#      95         The name of the colormap to use.
#      96     """
# ---> 97     ip = _get_image_properties(image)
#      98     immin, immax = np.min(image), np.max(image)
#      99     if ip.signed:
#
# File ~/Libraries/anaconda3/envs/opencl/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:45, in _get_image_properties(image)
#      22 """Determine nonstandard properties of an input image.
#      23
#      24 Parameters
#    (...)
#      42       standard skimage type, e.g. ``numpy.uint64``.
#      43 """
#      44 immin, immax = np.min(image), np.max(image)
# ---> 45 imtype = image.dtype.type
#      46 try:
#      47     lo, hi = dtypes.dtype_range[imtype]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'type'
