# %%
from skimage.io import imread, imshow
import pyclesperanto as cle

print("pyclesperanto",cle.__version__ , "- running with CLIc",cle.__clic_version__)
# Out:
# pyclesperanto 0.7.0 - running with CLIc 0.7.0

# %%
cle.list_available_backends()
# Out:
# ['cuda', 'opencl']

# %%
cle.select_backend(backend="cuda")
# Out:
# 'CUDA backend selected.'

# %%
cle.list_available_devices()
# Out:
# ['NVIDIA GeForce RTX 2080 SUPER']

# %%
device = cle.select_device()
print(device)
# Out:
# (CUDA) NVIDIA GeForce RTX 2080 SUPER

# %%
print(device.info)
# Out:
# (CUDA) NVIDIA GeForce RTX 2080 SUPER (11.7)
# 	Type: GPU
# 	Compute Units: 48
# 	Global Memory Size: 8366 MB

# %%
image = imread("https://imagej.nih.gov/ij/images/blobs.gif")
imshow(image)

# %%
blurred = cle.gaussian_blur(image, sigma_x=5, sigma_y=5)

# %%
cle.imshow(blurred)

# %%
for k in dir(cle):
    print(k)
# Out:
# Array
# DataType
# Device
# Image
# MemoryType
# __builtins__
# __cached__
# __clic_version__
# __common_alias__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# __version__
# _array
# _core
# _decorators
# _functionalities
# _memory
# _operators
# _pyclesperanto
# _tier1
# _tier2
# _types
# _version
# absolute
# add_image_and_scalar
# add_images_weighted
# binary_and
# binary_edge_detection
# binary_not
# binary_or
# binary_subtract
# binary_xor
# buffer
# convolve
# copy
# create
# create_like
# difference_of_gaussian
# dilate_box
# dilate_sphere
# divide_images
# equal
# equal_constant
# erode_box
# erode_sphere
# exponential
# gaussian_blur
# get_device
# gradient_x
# gradient_y
# gradient_z
# greater
# greater_constant
# greater_or_equal
# greater_or_equal_constant
# image
# imshow
# is_image
# laplace_box
# laplace_diamond
# list_available_backends
# list_available_devices
# logarithm
# mask
# mask_label
# maximum_box
# ...

# %%
blurred.max(axis=2)
# Out:
# array([220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
# ...

# %%
cle.imshow(blurred > 150)
